# %% [markdown]
# # DeepSeek API 访问方法
#
# ## 访问官网并注册
# 访问 https://platform.deepseek.com/usage
# ![alt text](./src/imgs/image1.png)
# ## 充值并创建API Key
# 访问 https://platform.deepseek.com/api_keys 创建API Key
# ![alt text](./src/imgs/image2.png)
#
# **保存好API Key，使用前建议把API Key设置成环境变量DEEPSEEK_API_KEY**
#
# ## 使用如下的方法调用API

# %%
import os
from langchain_openai import ChatOpenAI

deepseek_chat = ChatOpenAI(
            model="deepseek-chat",
            api_key=os.environ["DEEPSEEK_API_KEY"],
            base_url="https://api.deepseek.com",
            temperature=0,
        )
response = deepseek_chat.invoke("Hello, how are you?")   
print(response.content)
# Out:
# Hello! I'm doing well, thank you for asking! 😊 I'm here and ready to help you with anything you need—whether it's answering questions, brainstorming ideas, or just having a friendly chat. How are you doing today?
