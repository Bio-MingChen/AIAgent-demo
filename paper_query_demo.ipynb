# %% [markdown]
# # Paper Query Agent Demo
#
# This notebook runs the LangGraph-based literature search agent and renders its graph.

# %%
from paper_query.ai_agent import AIAgent
from IPython.display import Image, display

# %%
agent = AIAgent()
result = agent.run("AML treatment")
print(result.get("summary", result.get("answer", "")))
# Out:
# Search query: AML treatment | Count: 33479 | Report: report\AML_treatment_20260109_040913.html

# %%
display(Image(agent.get_graph().draw_mermaid_png()))
